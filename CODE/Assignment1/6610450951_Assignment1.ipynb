# %% [markdown]
# # Tontawan Janthai 6610450951

# %%
import pandas as pd

# %% [markdown]
# ## 1

# %%
medals = pd.read_csv("olympics_cleaned.csv")
medals.head()
# Out:
#        Country Code  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# 0  Afghanistan  AFG          13           0             0             2
# 1      Algeria  ALG          12           5             2             8
# 2    Argentina  ARG          23          18            24            28
# 3      Armenia  ARM           5           1             2             9
# 4  Australasia  ANZ           2           3             4             5
#
#    WinterGame  WinterGold  WinterSilver  WinterBronze
# 0           0           0             0             0
# 1           3           0             0             0
# 2          18           0             0             0
# 3           6           0             0             0
# 4           0           0             0             0

# %% [markdown]
# # 2

# %%
print(f"Rows: {medals.shape[0]}, Cols: {medals.shape[1]}")
# Out:
# Rows: 146, Cols: 10

# %% [markdown]
# # 3

# %%
medals.Code.is_unique
# Out:
# True

# %% [markdown]
# # 4

# %%
medals = medals.set_index('Code')
medals.head()
# Out:
#           Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# AFG   Afghanistan          13           0             0             2
# ALG       Algeria          12           5             2             8
# ARG     Argentina          23          18            24            28
# ARM       Armenia           5           1             2             9
# ANZ   Australasia           2           3             4             5
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# AFG            0           0             0             0
# ALG            3           0             0             0
# ARG           18           0             0             0
# ARM            6           0             0             0
# ANZ            0           0             0             0

# %% [markdown]
# # 5

# %%
medals.loc[:, ['SummerGold']]
# Out:
#       SummerGold
# Code
# AFG            0
# ALG            5
# ARG           18
# ARM            1
# ANZ            3
# ...          ...
# YUG           26
# IOP            0
# ZAM            0
# ZIM            3
# ZZX            8
#
# [146 rows x 1 columns]

# %% [markdown]
# # 6

# %%
medals.loc[ ["USA"], :]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# USA   United States          26         976           757           666
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# USA           22          96           102            84

# %% [markdown]
# # 7

# %%
medals.loc[:, medals.columns.str.startswith("Summer")]
# Out:
#       SummerGame  SummerGold  SummerSilver  SummerBronze
# Code
# AFG           13           0             0             2
# ALG           12           5             2             8
# ARG           23          18            24            28
# ARM            5           1             2             9
# ANZ            2           3             4             5
# ...          ...         ...           ...           ...
# YUG           16          26            29            28
# IOP            1           0             1             2
# ZAM           12           0             1             1
# ZIM           12           3             4             1
# ZZX            3           8             5             4
#
# [146 rows x 4 columns]

# %% [markdown]
# # 8

# %%
medals.loc[["THA", "SIN", "MAS"], medals.columns.str.contains("Gold") | (medals.columns == "Country")]
# Out:
#         Country  SummerGold  WinterGold
# Code
# THA    Thailand           7           0
# SIN   Singapore           0           0
# MAS    Malaysia           0           0

# %% [markdown]
# # 9

# %%
medals.loc[["FRA", "ESP"], medals.columns.str.contains("Gold") | medals.columns.str.contains("Bronze") | (medals.columns == "Country")]
# Out:
#      Country  SummerGold  SummerBronze  WinterGold  WinterBronze
# Code
# FRA   France         202           246          31            47
# ESP    Spain          37            35           1             1

# %% [markdown]
# # 10

# %%
medals.loc[ medals.SummerGame > 24 ]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# AUS       Australia          25         139           152           177
# AUT         Austria          26          18            33            35
# BEL         Belgium          25          37            52            53
# CAN          Canada          25          59            99           121
# DEN         Denmark          26          43            68            68
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# GRE          Greece          27          30            42            39
# HUN         Hungary          25         167           144           165
# ITA           Italy          26         198           166           185
# NED     Netherlands          25          77            85           104
# SWE          Sweden          26         143           164           176
# ...

# %% [markdown]
# # 11

# %%
medals[ medals.SummerGold > 200 ]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# CHN           China           9         201           146           126
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# URS    Soviet Union           9         395           319           296
# USA   United States          26         976           757           666
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# CHN           10          12            22            19
# FRA           22          31            31            47
# GBR           22          10             4            12
# URS            9          78            57            59
# USA           22          96           102            84

# %% [markdown]
# # 12

# %%
medals[ (medals.loc[:, medals.columns.str.contains("Summer")].sum(axis=1) > 200) & 
           (medals.loc[:, medals.columns.str.contains("Silver")].sum(axis=1) > 200) ]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# FRA          France          27         202           223           246
# GER         Germany          15         174           182           217
# GBR   Great Britain          27         236           272           272
# URS    Soviet Union           9         395           319           296
# SWE          Sweden          26         143           164           176
# USA   United States          26         976           757           666
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# FRA           22          31            31            47
# GER           11          78            78            53
# GBR           22          10             4            12
# URS            9          78            57            59
# SWE           22          50            40            54
# USA           22          96           102            84

# %% [markdown]
# # 13

# %%
medals[ medals.WinterGold > medals.WinterSilver]
# Out:
#                      Country  SummerGame  SummerGold  SummerSilver  \
# Code
# AUS                Australia          25         139           152
# BLR                  Belarus           5          12            24
# CAN                   Canada          25          59            99
# EST                  Estonia          11           9             9
# EUA   United Team of Germany           3          28            54
# GDR             East Germany           5         153           129
# GBR            Great Britain          27         236           272
# ITA                    Italy          26         198           166
# KOR              South Korea          16          81            82
# NOR                   Norway          24          56            49
# RUS                   Russia           5         132           121
# URS             Soviet Union           9         395           319
# EUN             Unified Team           1          45            38
# ...

# %% [markdown]
# # 14

# %%
medals[ medals.WinterGold > (medals.WinterSilver + medals.WinterBronze)]
# Out:
#          Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# EST      Estonia          11           9             9            15
# UZB   Uzbekistan           5           5             5            10
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# EST            9           4             2             1
# UZB            6           1             0             0

# %% [markdown]
# # 15

# %%
medals.loc[ medals.Country.str.startswith("A"), "Country":"SummerBronze"]
# Out:
#           Country  SummerGame  SummerGold  SummerSilver  SummerBronze
# Code
# AFG   Afghanistan          13           0             0             2
# ALG       Algeria          12           5             2             8
# ARG     Argentina          23          18            24            28
# ARM       Armenia           5           1             2             9
# ANZ   Australasia           2           3             4             5
# AUS     Australia          25         139           152           177
# AUT       Austria          26          18            33            35
# AZE    Azerbaijan           5           6             5            15

# %% [markdown]
# # 16

# %%
max(medals.SummerGame)
# Out:
# 27

# %% [markdown]
# # 17

# %%
medals[ medals.SummerGame == max(medals.SummerGame)]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# GRE          Greece          27          30            42            39
# SUI     Switzerland          27          47            73            65
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# FRA           22          31            31            47
# GBR           22          10             4            12
# GRE           18           0             0             0
# SUI           22          50            40            48

# %% [markdown]
# # 18

# %%
medals[ medals.WinterGame == max(medals.WinterGame)].shape[0]
# Out:
# 12

# %% [markdown]
# # 19

# %%
sum(medals.WinterGold + medals.WinterSilver + medals.WinterBronze)
# Out:
# 2865

# %% [markdown]
# # 20

# %%
Avg = (medals.WinterGold + medals.SummerGold) / 2

df20 = pd.DataFrame({
    "Country": medals.Country,
    "Avg": Avg
})

df20
# Out:
#                                Country   Avg
# Code
# AFG                        Afghanistan   0.0
# ALG                            Algeria   2.5
# ARG                          Argentina   9.0
# ARM                            Armenia   0.5
# ANZ                        Australasia   1.5
# ...                                ...   ...
# YUG                         Yugoslavia  13.0
# IOP   Independent Olympic Participants   0.0
# ZAM                             Zambia   0.0
# ZIM                           Zimbabwe   1.5
# ZZX                         Mixed team   4.0
#
# [146 rows x 2 columns]

# %% [markdown]
# # 21

# %%
Total = (medals.SummerGold + medals.SummerSilver + medals.SummerBronze) + (medals.WinterGold + medals.WinterSilver + medals.WinterBronze)

df21 = pd.DataFrame({
    "Country": medals.Country,
    "Total": Total
})

df21
# Out:
#                                Country  Total
# Code
# AFG                        Afghanistan      2
# ALG                            Algeria     15
# ARG                          Argentina     70
# ARM                            Armenia     12
# ANZ                        Australasia     12
# ...                                ...    ...
# YUG                         Yugoslavia     87
# IOP   Independent Olympic Participants      3
# ZAM                             Zambia      2
# ZIM                           Zimbabwe      8
# ZZX                         Mixed team     17
#
# [146 rows x 2 columns]

# %% [markdown]
# # 22

# %%
SummerSum = medals.SummerGold + medals.SummerSilver + medals.SummerBronze
WinterSum = medals.WinterGold + medals.WinterSilver + medals.WinterBronze

df22 = pd.DataFrame({    
    "Country": medals.Country,
    "TotalSummer": SummerSum,
    "TotalWinter": WinterSum
})

df22[df22.TotalSummer > df22.TotalWinter]
# Out:
#                                Country  TotalSummer  TotalWinter
# Code
# AFG                        Afghanistan            2            0
# ALG                            Algeria           15            0
# ARG                          Argentina           70            0
# ARM                            Armenia           12            0
# ANZ                        Australasia           12            0
# ...                                ...          ...          ...
# YUG                         Yugoslavia           83            4
# IOP   Independent Olympic Participants            3            0
# ZAM                             Zambia            2            0
# ZIM                           Zimbabwe            8            0
# ZZX                         Mixed team           17            0
#
# [142 rows x 3 columns]

# %% [markdown]
# # 23

# %%
SummerSum = medals.SummerGold + medals.SummerSilver + medals.SummerBronze
WinterSum = medals.WinterGold + medals.WinterSilver + medals.WinterBronze

df23 = pd.DataFrame({    
    "Country": medals.Country,
    "TotalSummer": SummerSum,
    "TotalWinter": WinterSum
})

df23[((df23.TotalSummer == 0) & (df23.TotalWinter > 0)) | ((df23.TotalSummer > 0) & (df23.TotalWinter == 0))]
# Out:
#                                Country  TotalSummer  TotalWinter
# Code
# AFG                        Afghanistan            2            0
# ALG                            Algeria           15            0
# ARG                          Argentina           70            0
# ARM                            Armenia           12            0
# ANZ                        Australasia           12            0
# ...                                ...          ...          ...
# ISV                     Virgin Islands            1            0
# IOP   Independent Olympic Participants            3            0
# ZAM                             Zambia            2            0
# ZIM                           Zimbabwe            8            0
# ZZX                         Mixed team           17            0
#
# [102 rows x 3 columns]

# %% [markdown]
# # 24

# %%
df24 = medals.sort_values("SummerGold", ascending=True)
df24
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# AFG     Afghanistan          13           0             0             2
# NAM         Namibia           6           0             4             0
# MNE      Montenegro           2           0             1             0
# MDA         Moldova           5           0             2             5
# MRI       Mauritius           8           0             0             1
# ...             ...         ...         ...           ...           ...
# CHN           China           9         201           146           126
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# URS    Soviet Union           9         395           319           296
# USA   United States          26         976           757           666
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# ...

# %% [markdown]
# # 25

# %%
df25 = medals.sort_values(["SummerGold", "SummerGame"], ascending=[False,True])
df25
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# USA   United States          26         976           757           666
# URS    Soviet Union           9         395           319           296
# GBR   Great Britain          27         236           272           272
# FRA          France          27         202           223           246
# CHN           China           9         201           146           126
# ...             ...         ...         ...           ...           ...
# SRI       Sri Lanka          16           0             2             0
# BER         Bermuda          17           0             0             1
# PUR     Puerto Rico          17           0             2             6
# ISL         Iceland          19           0             2             2
# PHI     Philippines          20           0             2             7
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# ...

# %% [markdown]
# # 26

# %%
medals["score"] = (3 * (medals.WinterGold + medals.SummerGold)) 
+ (2 * (medals.WinterSilver + medals.SummerSilver)) 
+ (1 * (medals.WinterBronze + medals.SummerBronze))

df26 = medals.sort_values("score", ascending=False)
df26.head(10)
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# USA   United States          26         976           757           666
# URS    Soviet Union           9         395           319           296
# GER         Germany          15         174           182           217
# GBR   Great Britain          27         236           272           272
# ITA           Italy          26         198           166           185
# FRA          France          27         202           223           246
# CHN           China           9         201           146           126
# SWE          Sweden          26         143           164           176
# GDR    East Germany           5         153           129           127
# RUS          Russia           5         132           121           142
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze  score
# Code
# USA           22          96           102            84   3216
# ...

# %% [markdown]
# # 27

# %%
import numpy as np

TotalScoreWinter = (3 * (medals.WinterGold)) + (2 * (medals.WinterSilver)) + (1 * (medals.WinterBronze))
TotalScoreSummer = (3 * (medals.SummerGold)) + (2 * (medals.SummerSilver)) + (1 * (medals.SummerBronze))

WinterScorePerGame = np.where(medals.WinterGame > 0, TotalScoreWinter / medals.WinterGame, 0)
SummerScorePerGame = np.where(medals.SummerGame > 0, TotalScoreSummer / medals.SummerGame, 0)

medals["perGame"] = WinterScorePerGame + SummerScorePerGame
df27 = medals.sort_values("perGame", ascending=True)
df27.head(10)
# Out:
#           Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# BER       Bermuda          17           0             0             1
# GUY        Guyana          16           0             0             1
# IRQ          Iraq          13           0             0             1
# NIG         Niger          11           0             0             1
# BAR      Barbados          11           0             0             1
# TOG          Togo           9           0             0             1
# MRI     Mauritius           8           0             0             1
# BRN       Bahrain           8           0             0             1
# DJI      Djibouti           7           0             0             1
# AFG   Afghanistan          13           0             0             2
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze  score   perGame
# Code
# BER            7           0             0             0      0  0.058824
# ...
